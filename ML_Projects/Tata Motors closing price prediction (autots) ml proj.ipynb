# %%
import pandas as pd
import numpy as np
import autots as AutoTS

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0043-65DD
#
#  Directory of C:\Users\henry\Machine learning projects
#
# 25/07/2022  12:06    <DIR>          .
# 25/07/2022  11:29    <DIR>          ..
# 25/07/2022  11:58    <DIR>          .ipynb_checkpoints
# 22/07/2022  16:21            95,813 Breast Cancer surgery success rate ml proj.ipynb
# 22/07/2022  11:36         4,780,881 Covid 19 forecaster (India).ipynb
# 25/07/2022  11:49         4,662,586 Netflix closing price stock prediction ml proj.ipynb
# 24/07/2022  16:19            25,539 Profit prediction ml proj.ipynb
# 24/07/2022  14:18            18,663 Sales prediction ml proj.ipynb
# 20/07/2022  17:33           129,435 Simple machine learning py project.ipynb
# 22/07/2022  17:35           455,161 Social media followers predictor ml proj.ipynb
# 22/07/2022  12:26           320,654 Travel Insurance prediction ml project.ipynb
# 25/07/2022  12:06            13,498 Untitled.ipynb
# 22/07/2022  12:55         3,986,286 Waiter tips prediction python .ipynb
#               10 File(s)     14,488,516 bytes
#                3 Dir(s)   9,162,657,792 bytes free

# %%
data = pd.read_csv("C:/Users/henry/Downloads/TTM.csv")
data.drop(data.index[[-1, -2, -3, -4, -5]], inplace=True)
print(data.tail())
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 241  11/07/2022  27.450001  27.540001  27.219999  27.260000  27.260000  341700
# 242  12/07/2022  26.940001  27.420000  26.860001  27.129999  27.129999  506800
# 243  13/07/2022  26.450001  26.879999  26.450001  26.620001  26.620001  541600
# 244  14/07/2022  26.389999  26.959999  26.280001  26.920000  26.920000  586700
# 245  15/07/2022  27.700001  27.840000  27.510000  27.820000  27.820000  713000

# %%
from autots import AutoTS
model = AutoTS(forecast_length=5, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Inferred frequency is: B
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 8/8 [==============================] - 6s 11ms/step - loss: 0.4001
# Epoch 2/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3945
# Epoch 3/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3970
# Epoch 4/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3948
# Epoch 5/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3898
# Epoch 6/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3886
# Epoch 7/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3834
# Epoch 8/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3756
# Epoch 9/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3723
# Epoch 10/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3650
# Epoch 11/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3536
# Epoch 12/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3373
# Epoch 13/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3213
# Epoch 14/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3055
# Epoch 15/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2808
# Epoch 16/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2756
# Epoch 17/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2665
# Epoch 18/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2544
# Epoch 19/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2412
# Epoch 20/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2423
# Epoch 21/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2346
# Epoch 22/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2253
# Epoch 23/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2222
# Epoch 24/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2249
# Epoch 25/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2314
# Epoch 26/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2215
# Epoch 27/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2104
# Epoch 28/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2191
# Epoch 29/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2208
# Epoch 30/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2127
# Epoch 31/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2122
# Epoch 32/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2152
# Epoch 33/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2141
# Epoch 34/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2065
# Epoch 35/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2029
# Epoch 36/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2026
# Epoch 37/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1941
# Epoch 38/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1984
# Epoch 39/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2003
# Epoch 40/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1916
# Epoch 41/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1928
# Epoch 42/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1920
# Epoch 43/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1921
# Epoch 44/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1902
# Epoch 45/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1851
# Epoch 46/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1806
# Epoch 47/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1928
# Epoch 48/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1859
# Epoch 49/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1768
# Epoch 50/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1861
# 1/1 [==============================] - 1s 810ms/step
# Model Number: 8 with model ETS in generation 0 of 10
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 10: GLM
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model LastValueNaive in generation 0 of 10
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model SeasonalNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model UnobservedComponents in generation 0 of 10
# Model Number: 27 with model UnobservedComponents in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Model Number: 29 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 29: VAR
# Model Number: 30 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 30: VAR
# Model Number: 31 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 31: VECM
# Model Number: 32 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 32: VECM
# Model Number: 33 with model WindowRegression in generation 0 of 10
# Model Number: 34 with model ConstantNaive in generation 0 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 35 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 35: FBProphet
# Model Number: 36 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 36: GluonTS
# Model Number: 37 with model MultivariateRegression in generation 0 of 10
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 170 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    0.1s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# Model Number: 38 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 38: MultivariateRegression
# Model Number: 39 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 39: DatepartRegression
# Model Number: 40 with model SeasonalNaive in generation 0 of 10
# Model Number: 41 with model DatepartRegression in generation 0 of 10
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# Model Number: 42 with model UnobservedComponents in generation 0 of 10
# Model Number: 43 with model UnobservedComponents in generation 0 of 10
# Model Number: 44 with model ETS in generation 0 of 10
# Model Number: 45 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 45: VECM
# Model Number: 46 with model ARDL in generation 0 of 10
# Model Number: 47 with model MultivariateMotif in generation 0 of 10
# Model Number: 48 with model MultivariateMotif in generation 0 of 10
# Model Number: 49 with model UnivariateMotif in generation 0 of 10
# Model Number: 50 with model UnivariateMotif in generation 0 of 10
# Model Number: 51 with model SectionalMotif in generation 0 of 10
# Model Number: 52 with model SectionalMotif in generation 0 of 10
# Model Number: 53 with model MultivariateRegression in generation 0 of 10
# Model Number: 54 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 54: FBProphet
# Model Number: 55 with model SeasonalNaive in generation 0 of 10
# Model Number: 56 with model DatepartRegression in generation 0 of 10
# Model Number: 57 with model NVAR in generation 0 of 10
# Model Number: 58 with model Theta in generation 0 of 10
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 59 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 59: UnivariateRegression
# Model Number: 60 with model ConstantNaive in generation 0 of 10
# Model Number: 61 with model LastValueNaive in generation 0 of 10
# Model Number: 62 with model AverageValueNaive in generation 0 of 10
# Model Number: 63 with model GLS in generation 0 of 10
# Model Number: 64 with model SeasonalNaive in generation 0 of 10
# Model Number: 65 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 65: GLM
# Model Number: 66 with model ETS in generation 0 of 10
# Model Number: 67 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 67: FBProphet
# Model Number: 68 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 68: GluonTS
# Model Number: 69 with model UnobservedComponents in generation 0 of 10
# Model Number: 70 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 70: VAR
# Model Number: 71 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 71: VECM
# Model Number: 72 with model WindowRegression in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'lightgbm'") in model 72: WindowRegression
# Model Number: 73 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 73: DatepartRegression
# Model Number: 74 with model UnivariateRegression in generation 0 of 10
# Model Number: 75 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 75: MultivariateRegression
# Model Number: 76 with model UnivariateMotif in generation 0 of 10
# Model Number: 77 with model MultivariateMotif in generation 0 of 10
# Model Number: 78 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series. fail_on_forecast_nan=True') in model 78: SectionalMotif
# Model Number: 79 with model NVAR in generation 0 of 10
# Model Number: 80 with model Theta in generation 0 of 10
# Model Number: 81 with model ARDL in generation 0 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\autots\tools\percentile.py:47: RuntimeWarning: All-NaN slice encountered
#   max_val = np.nanmax(arr)
# Model Number: 82 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 82: VAR
# Model Number: 83 with model WindowRegression in generation 0 of 10
# Model Number: 84 with model GLM in generation 0 of 10
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 84: GLM
# Model Number: 85 with model NVAR in generation 0 of 10
# Model Number: 86 with model LastValueNaive in generation 0 of 10
# Model Number: 87 with model LastValueNaive in generation 0 of 10
# Model Number: 88 with model LastValueNaive in generation 0 of 10
# Model Number: 89 with model LastValueNaive in generation 0 of 10
# Model Number: 90 with model UnivariateMotif in generation 0 of 10
# Model Number: 91 with model GLM in generation 0 of 10
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 91: GLM
# Model Number: 92 with model ConstantNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on inverse') in model 92: ConstantNaive
# Model Number: 93 with model GLM in generation 0 of 10
# Template Eval Error: TypeError("ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''") in model 93: GLM
# Model Number: 94 with model MultivariateMotif in generation 0 of 10
# Model Number: 95 with model LastValueNaive in generation 0 of 10
# Model Number: 96 with model GLS in generation 0 of 10
# Model Number: 97 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 97: UnobservedComponents
# Model Number: 98 with model ETS in generation 0 of 10
# Model Number: 99 with model UnivariateMotif in generation 0 of 10
# Model Number: 100 with model LastValueNaive in generation 0 of 10
# Model Number: 101 with model ConstantNaive in generation 0 of 10
# Model Number: 102 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 102: VAR
# Model Number: 103 with model LastValueNaive in generation 0 of 10
# Model Number: 104 with model AverageValueNaive in generation 0 of 10
# Model Number: 105 with model SectionalMotif in generation 0 of 10
# Model Number: 106 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('Model MultivariateMotif returned NaN for one or more series. fail_on_forecast_nan=True') in model 106: MultivariateMotif
# Model Number: 107 with model UnobservedComponents in generation 0 of 10
# Model Number: 108 with model WindowRegression in generation 0 of 10
# Model Number: 109 with model Theta in generation 0 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\numpy\core\_methods.py:48: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Model Number: 110 with model ConstantNaive in generation 0 of 10
# Model Number: 111 with model NVAR in generation 0 of 10
# Model Number: 112 with model ConstantNaive in generation 0 of 10
# Model Number: 113 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 113: FBProphet
# Model Number: 114 with model ConstantNaive in generation 0 of 10
# Model Number: 115 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 4/4 [==============================] - 4s 7ms/step - loss: 108.0496
# Epoch 2/50
# 4/4 [==============================] - 0s 8ms/step - loss: 105.8925
# Epoch 3/50
# 4/4 [==============================] - 0s 7ms/step - loss: 103.4435
# Epoch 4/50
# 4/4 [==============================] - 0s 7ms/step - loss: 105.7559
# Epoch 5/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.6014
# Epoch 6/50
# 4/4 [==============================] - 0s 8ms/step - loss: 105.0522
# Epoch 7/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.7432
# Epoch 8/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.3087
# Epoch 9/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.3082
# Epoch 10/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.3132
# Epoch 11/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.3789
# Epoch 12/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.7951
# Epoch 13/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.9558
# Epoch 14/50
# 4/4 [==============================] - 0s 8ms/step - loss: 101.7219
# Epoch 15/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.0920
# Epoch 16/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.5214
# Epoch 17/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.4967
# Epoch 18/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.4652
# Epoch 19/50
# 4/4 [==============================] - 0s 9ms/step - loss: 101.4950
# Epoch 20/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.1427
# Epoch 21/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.5192
# Epoch 22/50
# 4/4 [==============================] - 0s 8ms/step - loss: 105.1742
# Epoch 23/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.0260
# Epoch 24/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.1681
# Epoch 25/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.0132
# Epoch 26/50
# 4/4 [==============================] - 0s 8ms/step - loss: 102.8444
# Epoch 27/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.0306
# Epoch 28/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.1983
# Epoch 29/50
# 4/4 [==============================] - 0s 8ms/step - loss: 98.9992
# Epoch 30/50
# 4/4 [==============================] - 0s 9ms/step - loss: 99.5015
# Epoch 31/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.5174
# Epoch 32/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.3724
# Epoch 33/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.7754
# Epoch 34/50
# 4/4 [==============================] - 0s 8ms/step - loss: 98.9497
# Epoch 35/50
# 4/4 [==============================] - 0s 8ms/step - loss: 101.4214
# Epoch 36/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.1251
# Epoch 37/50
# 4/4 [==============================] - 0s 8ms/step - loss: 98.1631
# Epoch 38/50
# 4/4 [==============================] - 0s 9ms/step - loss: 96.8529
# Epoch 39/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.1061
# Epoch 40/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.9913
# Epoch 41/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.6916
# Epoch 42/50
# 4/4 [==============================] - 0s 9ms/step - loss: 100.1599
# Epoch 43/50
# 4/4 [==============================] - 0s 8ms/step - loss: 101.1725
# Epoch 44/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.4795
# Epoch 45/50
# 4/4 [==============================] - 0s 9ms/step - loss: 97.9589
# Epoch 46/50
# 4/4 [==============================] - 0s 8ms/step - loss: 100.0502
# Epoch 47/50
# 4/4 [==============================] - 0s 9ms/step - loss: 100.3040
# Epoch 48/50
# 4/4 [==============================] - 0s 8ms/step - loss: 98.7125
# Epoch 49/50
# 4/4 [==============================] - 0s 8ms/step - loss: 99.9273
# Epoch 50/50
# 4/4 [==============================] - 0s 8ms/step - loss: 98.8010
# 1/1 [==============================] - 1s 821ms/step
# Model Number: 116 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 116: FBProphet
# Model Number: 117 with model ETS in generation 0 of 10
# Model Number: 118 with model ConstantNaive in generation 0 of 10
# Model Number: 119 with model UnivariateMotif in generation 0 of 10
# Model Number: 120 with model ConstantNaive in generation 0 of 10
# Model Number: 121 with model SeasonalNaive in generation 0 of 10
# Model Number: 122 with model SeasonalNaive in generation 0 of 10
# Model Number: 123 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 123: VAR
# Model Number: 124 with model GLS in generation 0 of 10
# Model Number: 125 with model WindowRegression in generation 0 of 10
# Epoch 1/50
# 15/15 [==============================] - 4s 4ms/step - loss: nan
# Epoch 2/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 3/50
# 15/15 [==============================] - 0s 5ms/step - loss: nan
# Epoch 4/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 5/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 6/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 7/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 8/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 9/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 10/50
# 15/15 [==============================] - 0s 5ms/step - loss: nan
# Epoch 11/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 12/50
# 15/15 [==============================] - 0s 5ms/step - loss: nan
# Epoch 13/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 14/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 15/50
# 15/15 [==============================] - 0s 5ms/step - loss: nan
# Epoch 16/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 17/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 18/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 19/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 20/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 21/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 22/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 23/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 24/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 25/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 26/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 27/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 28/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 29/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 30/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 31/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 32/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 33/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 34/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 35/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 36/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 37/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 38/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 39/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 40/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 41/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 42/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 43/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 44/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 45/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 46/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 47/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 48/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 49/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# Epoch 50/50
# 15/15 [==============================] - 0s 4ms/step - loss: nan
# 1/1 [==============================] - 1s 754ms/step
# Model Number: 126 with model UnivariateMotif in generation 0 of 10
# Model Number: 127 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 127: WindowRegression
# Model Number: 128 with model SeasonalNaive in generation 0 of 10
# Model Number: 129 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'zero', 'transformations': {'0': 'CumSumTransformer', '1': 'cffilter', '2': 'IntermittentOccurrence'}, 'transformation_params': {'0': {}, '1': {}, '2': {'center': 'mean'}}}. fail_on_forecast_nan=True") in model 129: MultivariateMotif
# Model Number: 130 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 130: ARDL
# Model Number: 131 with model ConstantNaive in generation 0 of 10
# Model Number: 132 with model ETS in generation 0 of 10
# Model Number: 133 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 133: UnobservedComponents
# Model Number: 134 with model DatepartRegression in generation 0 of 10
# Template Eval Error: Exception('Transformer StandardScaler failed on fit') in model 134: DatepartRegression
# Model Number: 135 with model NVAR in generation 0 of 10
# Model Number: 136 with model SectionalMotif in generation 0 of 10
# Model Number: 137 with model NVAR in generation 0 of 10
# Model Number: 138 with model SeasonalNaive in generation 0 of 10
# Model Number: 139 with model LastValueNaive in generation 0 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\utils\extmath.py:985: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\utils\extmath.py:990: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\utils\extmath.py:1020: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# Model Number: 140 with model MultivariateMotif in generation 0 of 10
# Model Number: 141 with model ConstantNaive in generation 0 of 10
# Model Number: 142 with model ETS in generation 0 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 143 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 143: ARDL
# Model Number: 144 with model DatepartRegression in generation 0 of 10
# Model Number: 145 with model NVAR in generation 0 of 10
# Model Number: 146 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 146: VAR
# Model Number: 147 with model SeasonalNaive in generation 0 of 10
# Model Number: 148 with model GLS in generation 0 of 10
# Model Number: 149 with model AverageValueNaive in generation 0 of 10
# Model Number: 150 with model ConstantNaive in generation 0 of 10
# Model Number: 151 with model SectionalMotif in generation 0 of 10
# Model Number: 152 with model ConstantNaive in generation 0 of 10
# Model Number: 153 with model LastValueNaive in generation 0 of 10
# Model Number: 154 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 154: FBProphet
# Model Number: 155 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 155: GluonTS
# Model Number: 156 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 156: VAR
# Model Number: 157 with model MultivariateMotif in generation 0 of 10
# Model Number: 158 with model GLS in generation 0 of 10
# Model Number: 159 with model GLM in generation 0 of 10
# Model Number: 160 with model LastValueNaive in generation 0 of 10
# Model Number: 161 with model MultivariateMotif in generation 0 of 10
# Model Number: 162 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 162: VAR
# Model Number: 163 with model LastValueNaive in generation 0 of 10
# Model Number: 164 with model NVAR in generation 0 of 10
# Model Number: 165 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 165: GluonTS
# Model Number: 166 with model MultivariateMotif in generation 0 of 10
# Model Number: 167 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 167: ARDL
# Model Number: 168 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 168: SectionalMotif
# Model Number: 169 with model AverageValueNaive in generation 0 of 10
# New Generation: 1 of 10
# Model Number: 170 with model LastValueNaive in generation 1 of 10
# Model Number: 171 with model UnivariateMotif in generation 1 of 10
# Model Number: 172 with model ETS in generation 1 of 10
# Model Number: 173 with model AverageValueNaive in generation 1 of 10
# Model Number: 174 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 174: UnobservedComponents
# Model Number: 175 with model NVAR in generation 1 of 10
# Model Number: 176 with model MultivariateRegression in generation 1 of 10
# Model Number: 177 with model Theta in generation 1 of 10
# Model Number: 178 with model ETS in generation 1 of 10
# Model Number: 179 with model WindowRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 179: WindowRegression
# Model Number: 180 with model SectionalMotif in generation 1 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 180: SectionalMotif
# Model Number: 181 with model MultivariateMotif in generation 1 of 10
# Model Number: 182 with model MultivariateRegression in generation 1 of 10
# Model Number: 183 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 183: DatepartRegression
# Model Number: 184 with model SeasonalNaive in generation 1 of 10
# Model Number: 185 with model ConstantNaive in generation 1 of 10
# Model Number: 186 with model ConstantNaive in generation 1 of 10
# Model Number: 187 with model ConstantNaive in generation 1 of 10
# Model Number: 188 with model MultivariateRegression in generation 1 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 170 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    0.1s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# Model Number: 189 with model LastValueNaive in generation 1 of 10
# Model Number: 190 with model AverageValueNaive in generation 1 of 10
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 200 out of 200 | elapsed:    0.0s finished
# Model Number: 191 with model ConstantNaive in generation 1 of 10
# Model Number: 192 with model AverageValueNaive in generation 1 of 10
# Model Number: 193 with model UnobservedComponents in generation 1 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: invalid value encountered in add
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\glm.py:323: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# Model Number: 194 with model ETS in generation 1 of 10
# Model Number: 195 with model WindowRegression in generation 1 of 10
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# Model Number: 196 with model GLM in generation 1 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 196: GLM
# Model Number: 197 with model WindowRegression in generation 1 of 10
# Model Number: 198 with model LastValueNaive in generation 1 of 10
# Model Number: 199 with model LastValueNaive in generation 1 of 10
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.4s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\statsmodels\genmod\families\family.py:1346: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# Model Number: 200 with model ETS in generation 1 of 10
# Model Number: 201 with model GLM in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 201: GLM
# Model Number: 202 with model AverageValueNaive in generation 1 of 10
# Model Number: 203 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 203: UnobservedComponents
# Model Number: 204 with model ARDL in generation 1 of 10
# Model Number: 205 with model UnivariateRegression in generation 1 of 10
# Model Number: 206 with model SectionalMotif in generation 1 of 10
# Model Number: 207 with model UnobservedComponents in generation 1 of 10
# Model Number: 208 with model SectionalMotif in generation 1 of 10
# Model Number: 209 with model UnobservedComponents in generation 1 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# Model Number: 210 with model SeasonalNaive in generation 1 of 10
# Model Number: 211 with model AverageValueNaive in generation 1 of 10
# Model Number: 212 with model AverageValueNaive in generation 1 of 10
# Model Number: 213 with model DatepartRegression in generation 1 of 10
# Model Number: 214 with model GLS in generation 1 of 10
# Model Number: 215 with model ConstantNaive in generation 1 of 10
# Model Number: 216 with model LastValueNaive in generation 1 of 10
# Model Number: 217 with model ConstantNaive in generation 1 of 10
# Model Number: 218 with model GLS in generation 1 of 10
# Model Number: 219 with model NVAR in generation 1 of 10
# Model Number: 220 with model ConstantNaive in generation 1 of 10
# Model Number: 221 with model UnivariateRegression in generation 1 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: invalid value encountered in add
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\glm.py:323: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# Model Number: 222 with model DatepartRegression in generation 1 of 10
# Model Number: 223 with model SectionalMotif in generation 1 of 10
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 224 with model ETS in generation 1 of 10
# Model Number: 225 with model LastValueNaive in generation 1 of 10
# Model Number: 226 with model AverageValueNaive in generation 1 of 10
# Model Number: 227 with model ETS in generation 1 of 10
# Model Number: 228 with model SeasonalNaive in generation 1 of 10
# Model Number: 229 with model MultivariateMotif in generation 1 of 10
# Model Number: 230 with model UnivariateMotif in generation 1 of 10
# Model Number: 231 with model NVAR in generation 1 of 10
# Model Number: 232 with model NVAR in generation 1 of 10
# Model Number: 233 with model ConstantNaive in generation 1 of 10
# Model Number: 234 with model SeasonalNaive in generation 1 of 10
# Model Number: 235 with model Theta in generation 1 of 10
# Model Number: 236 with model SeasonalNaive in generation 1 of 10
# Model Number: 237 with model Theta in generation 1 of 10
# Model Number: 238 with model UnivariateMotif in generation 1 of 10
# Model Number: 239 with model WindowRegression in generation 1 of 10
# Model Number: 240 with model UnivariateMotif in generation 1 of 10
# Model Number: 241 with model SeasonalNaive in generation 1 of 10
# Model Number: 242 with model SectionalMotif in generation 1 of 10
# Model Number: 243 with model UnobservedComponents in generation 1 of 10
# Model Number: 244 with model Theta in generation 1 of 10
# Model Number: 245 with model MultivariateMotif in generation 1 of 10
# Model Number: 246 with model LastValueNaive in generation 1 of 10
# Model Number: 247 with model AverageValueNaive in generation 1 of 10
# Model Number: 248 with model LastValueNaive in generation 1 of 10
# Model Number: 249 with model AverageValueNaive in generation 1 of 10
# Model Number: 250 with model UnivariateMotif in generation 1 of 10
# Model Number: 251 with model ETS in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 251: ETS
# Model Number: 252 with model UnivariateMotif in generation 1 of 10
# Model Number: 253 with model LastValueNaive in generation 1 of 10
# Model Number: 254 with model MultivariateMotif in generation 1 of 10
# Model Number: 255 with model LastValueNaive in generation 1 of 10
# Model Number: 256 with model MultivariateMotif in generation 1 of 10
# Model Number: 257 with model ETS in generation 1 of 10
# ...
# Model Number: 69 of 166 with model SectionalMotif for Validation 3
# 69 - SectionalMotif with avg smape 18.42:
# Model Number: 70 of 166 with model SectionalMotif for Validation 3
# 70 - SectionalMotif with avg smape 3.6:
# Model Number: 71 of 166 with model ETS for Validation 3
# 71 - ETS with avg smape 2.05:
# Model Number: 72 of 166 with model MultivariateMotif for Validation 3
# 72 - MultivariateMotif with avg smape 1.89:
# Model Number: 73 of 166 with model ETS for Validation 3
# 73 - ETS with avg smape 2.11:
# Model Number: 74 of 166 with model SectionalMotif for Validation 3
# 74 - SectionalMotif with avg smape 4.54:
# Model Number: 75 of 166 with model SectionalMotif for Validation 3
# 75 - SectionalMotif with avg smape 8.22:
# Model Number: 76 of 166 with model ETS for Validation 3
# 76 - ETS with avg smape 2.06:
# Model Number: 77 of 166 with model ConstantNaive for Validation 3
# 77 - ConstantNaive with avg smape 6.0:
# Model Number: 78 of 166 with model ConstantNaive for Validation 3
# 78 - ConstantNaive with avg smape 6.01:
# Model Number: 79 of 166 with model MultivariateMotif for Validation 3
# 79 - MultivariateMotif with avg smape 7.73:
# Model Number: 80 of 166 with model MultivariateMotif for Validation 3
# 80 - MultivariateMotif with avg smape 4.99:
# Model Number: 81 of 166 with model MultivariateMotif for Validation 3
# 📈 81 - MultivariateMotif with avg smape 1.38:
# Model Number: 82 of 166 with model NVAR for Validation 3
# 82 - NVAR with avg smape 5.09:
# Model Number: 83 of 166 with model SectionalMotif for Validation 3
# 83 - SectionalMotif with avg smape 7.3:
# Model Number: 84 of 166 with model NVAR for Validation 3
# 84 - NVAR with avg smape 5.16:
# Model Number: 85 of 166 with model NVAR for Validation 3
# 85 - NVAR with avg smape 4.54:
# Model Number: 86 of 166 with model SectionalMotif for Validation 3
# 86 - SectionalMotif with avg smape 4.56:
# Model Number: 87 of 166 with model LastValueNaive for Validation 3
# 87 - LastValueNaive with avg smape 5.89:
# Model Number: 88 of 166 with model ConstantNaive for Validation 3
# 88 - ConstantNaive with avg smape 4.52:
# Model Number: 89 of 166 with model LastValueNaive for Validation 3
# 89 - LastValueNaive with avg smape 1.51:
# Model Number: 90 of 166 with model LastValueNaive for Validation 3
# 90 - LastValueNaive with avg smape 1.51:
# Model Number: 91 of 166 with model MultivariateMotif for Validation 3
# 91 - MultivariateMotif with avg smape 7.75:
# Model Number: 92 of 166 with model NVAR for Validation 3
# 92 - NVAR with avg smape 5.11:
# Model Number: 93 of 166 with model MultivariateMotif for Validation 3
# 93 - MultivariateMotif with avg smape 7.75:
# Model Number: 94 of 166 with model UnivariateRegression for Validation 3
# 94 - UnivariateRegression with avg smape 1.91:
# Model Number: 95 of 166 with model ARDL for Validation 3
# 95 - ARDL with avg smape 6.66:
# Model Number: 96 of 166 with model NVAR for Validation 3
# 96 - NVAR with avg smape 7.32:
# Model Number: 97 of 166 with model Theta for Validation 3
# 97 - Theta with avg smape 3.49:
# Model Number: 98 of 166 with model ConstantNaive for Validation 3
# 98 - ConstantNaive with avg smape 6.33:
# Model Number: 99 of 166 with model NVAR for Validation 3
# 99 - NVAR with avg smape 7.08:
# Model Number: 100 of 166 with model ConstantNaive for Validation 3
# 100 - ConstantNaive with avg smape 6.34:
# Model Number: 101 of 166 with model ConstantNaive for Validation 3
# 101 - ConstantNaive with avg smape 6.29:
# Model Number: 102 of 166 with model GLS for Validation 3
# 102 - GLS with avg smape 4.05:
# Model Number: 103 of 166 with model UnivariateRegression for Validation 3
# 103 - UnivariateRegression with avg smape 6.0:
# Model Number: 104 of 166 with model GLS for Validation 3
# 104 - GLS with avg smape 4.06:
# Model Number: 105 of 166 with model UnivariateRegression for Validation 3
# 105 - UnivariateRegression with avg smape 5.55:
# Model Number: 106 of 166 with model NVAR for Validation 3
# 106 - NVAR with avg smape 4.4:
# Model Number: 107 of 166 with model GLS for Validation 3
# 107 - GLS with avg smape 3.34:
# Model Number: 108 of 166 with model UnivariateRegression for Validation 3
# 108 - UnivariateRegression with avg smape 2.12:
# Model Number: 109 of 166 with model Theta for Validation 3
# 109 - Theta with avg smape 3.41:
# Model Number: 110 of 166 with model GLS for Validation 3
# 110 - GLS with avg smape 2.56:
# Model Number: 111 of 166 with model GLS for Validation 3
# 111 - GLS with avg smape 2.56:
# Model Number: 112 of 166 with model GLS for Validation 3
# 112 - GLS with avg smape 2.56:
# Model Number: 113 of 166 with model GLS for Validation 3
# 📈 113 - GLS with avg smape 1.34:
# Model Number: 114 of 166 with model GLS for Validation 3
# 114 - GLS with avg smape 2.56:
# Model Number: 115 of 166 with model Theta for Validation 3
# 115 - Theta with avg smape 3.26:
# Model Number: 116 of 166 with model Theta for Validation 3
# 116 - Theta with avg smape 3.62:
# Model Number: 117 of 166 with model Theta for Validation 3
# 117 - Theta with avg smape 3.68:
# Model Number: 118 of 166 with model ConstantNaive for Validation 3
# 118 - ConstantNaive with avg smape 6.64:
# Model Number: 119 of 166 with model Theta for Validation 3
# 119 - Theta with avg smape 3.67:
# Model Number: 120 of 166 with model Theta for Validation 3
# 120 - Theta with avg smape 1.71:
# Model Number: 121 of 166 with model Theta for Validation 3
# 121 - Theta with avg smape 3.39:
# Model Number: 122 of 166 with model UnivariateRegression for Validation 3
# 122 - UnivariateRegression with avg smape 5.32:
# Model Number: 123 of 166 with model ConstantNaive for Validation 3
# 123 - ConstantNaive with avg smape 3.13:
# Model Number: 124 of 166 with model UnivariateRegression for Validation 3
# 124 - UnivariateRegression with avg smape 5.91:
# Model Number: 125 of 166 with model ConstantNaive for Validation 3
# 125 - ConstantNaive with avg smape 2.99:
# Model Number: 126 of 166 with model WindowRegression for Validation 3
# 126 - WindowRegression with avg smape 4.0:
# Model Number: 127 of 166 with model UnobservedComponents for Validation 3
# 127 - UnobservedComponents with avg smape 3.82:
# Model Number: 128 of 166 with model WindowRegression for Validation 3
# 128 - WindowRegression with avg smape 3.35:
# Model Number: 129 of 166 with model WindowRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# 129 - WindowRegression with avg smape 4.33:
# Model Number: 130 of 166 with model WindowRegression for Validation 3
# 130 - WindowRegression with avg smape 2.28:
# Model Number: 131 of 166 with model Ensemble for Validation 3
# 131 - Ensemble with avg smape 5.21:
# Model Number: 132 of 166 with model SeasonalNaive for Validation 3
# 132 - SeasonalNaive with avg smape 6.31:
# Model Number: 133 of 166 with model SeasonalNaive for Validation 3
# 133 - SeasonalNaive with avg smape 4.21:
# Model Number: 134 of 166 with model SeasonalNaive for Validation 3
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\scipy\interpolate\polyint.py:545: RuntimeWarning: overflow encountered in multiply
#   self.wi[:j] *= (self.xi[j]-self.xi[:j])
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\scipy\interpolate\polyint.py:546: RuntimeWarning: overflow encountered in reduce
#   self.wi[j] = np.multiply.reduce(self.xi[:j]-self.xi[j])
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\scipy\interpolate\polyint.py:643: RuntimeWarning: invalid value encountered in true_divide
#   p = np.dot(c,self.yi)/np.sum(c,axis=-1)[...,np.newaxis]
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\scipy\interpolate\polyint.py:545: RuntimeWarning: overflow encountered in multiply
#   self.wi[:j] *= (self.xi[j]-self.xi[:j])
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\scipy\interpolate\polyint.py:546: RuntimeWarning: overflow encountered in reduce
#   self.wi[j] = np.multiply.reduce(self.xi[:j]-self.xi[j])
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\scipy\interpolate\polyint.py:643: RuntimeWarning: invalid value encountered in true_divide
#   p = np.dot(c,self.yi)/np.sum(c,axis=-1)[...,np.newaxis]
# 134 - SeasonalNaive with avg smape 5.64:
# Model Number: 135 of 166 with model UnobservedComponents for Validation 3
# 135 - UnobservedComponents with avg smape 4.86:
# Model Number: 136 of 166 with model WindowRegression for Validation 3
# 136 - WindowRegression with avg smape 3.95:
# Model Number: 137 of 166 with model UnobservedComponents for Validation 3
# 137 - UnobservedComponents with avg smape 4.77:
# Model Number: 138 of 166 with model UnobservedComponents for Validation 3
# 138 - UnobservedComponents with avg smape 3.77:
# Model Number: 139 of 166 with model UnobservedComponents for Validation 3
# 139 - UnobservedComponents with avg smape 4.99:
# Model Number: 140 of 166 with model UnobservedComponents for Validation 3
# 140 - UnobservedComponents with avg smape 5.64:
# Model Number: 141 of 166 with model ARDL for Validation 3
# 141 - ARDL with avg smape 2.43:
# Model Number: 142 of 166 with model ARDL for Validation 3
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\henry\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# 142 - ARDL with avg smape 1.61:
# Model Number: 143 of 166 with model ARDL for Validation 3
# 143 - ARDL with avg smape 2.29:
# Model Number: 144 of 166 with model WindowRegression for Validation 3
# 144 - WindowRegression with avg smape 2.28:
# Model Number: 145 of 166 with model SeasonalNaive for Validation 3
# 145 - SeasonalNaive with avg smape 6.39:
# Model Number: 146 of 166 with model WindowRegression for Validation 3
# 📈 146 - WindowRegression with avg smape 1.16:
# Model Number: 147 of 166 with model DatepartRegression for Validation 3
# 147 - DatepartRegression with avg smape 17.36:
# Model Number: 148 of 166 with model SeasonalNaive for Validation 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# 148 - SeasonalNaive with avg smape 2.92:
# Model Number: 149 of 166 with model DatepartRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# 149 - DatepartRegression with avg smape 11.93:
# Model Number: 150 of 166 with model ARDL for Validation 3
# 150 - ARDL with avg smape 2.75:
# Model Number: 151 of 166 with model ARDL for Validation 3
# 151 - ARDL with avg smape 1.99:
# Model Number: 152 of 166 with model ARDL for Validation 3
# 152 - ARDL with avg smape 2.35:
# Model Number: 153 of 166 with model DatepartRegression for Validation 3
# 153 - DatepartRegression with avg smape 4.0:
# Model Number: 154 of 166 with model SeasonalNaive for Validation 3
# 📈 154 - SeasonalNaive with avg smape 1.15:
# Model Number: 155 of 166 with model SeasonalNaive for Validation 3
# 155 - SeasonalNaive with avg smape 7.5:
# Model Number: 156 of 166 with model DatepartRegression for Validation 3
# 156 - DatepartRegression with avg smape 1.5:
# Model Number: 157 of 166 with model DatepartRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# 157 - DatepartRegression with avg smape 19.96:
# Model Number: 158 of 166 with model DatepartRegression for Validation 3
# 158 - DatepartRegression with avg smape 7.76:
# Model Number: 159 of 166 with model DatepartRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    0.0s
# 159 - DatepartRegression with avg smape 8.23:
# Model Number: 160 of 166 with model DatepartRegression for Validation 3
# 160 - DatepartRegression with avg smape 1.78:
# Model Number: 161 of 166 with model GLM for Validation 3
# 161 - GLM with avg smape 9.07:
# Model Number: 162 of 166 with model GLM for Validation 3
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=15)]: Using backend ThreadingBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=15)]: Done 100 out of 100 | elapsed:    0.0s finished
# 162 - GLM with avg smape 9.07:
# Model Number: 163 of 166 with model GLM for Validation 3
# 163 - GLM with avg smape 9.14:
# Model Number: 164 of 166 with model GLM for Validation 3
# 164 - GLM with avg smape 9.18:
# Model Number: 165 of 166 with model ARDL for Validation 3
# 165 - ARDL with avg smape 4.31:
# Model Number: 166 of 166 with model GLM for Validation 3
# 166 - GLM with avg smape 5.54:
#                 Close
# 2022-07-18  27.031933
# 2022-07-19  27.026000
# 2022-07-20  26.965567
# 2022-07-21  27.126349
# 2022-07-22  27.401037
